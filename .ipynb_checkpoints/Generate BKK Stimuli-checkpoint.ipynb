# %%
import numpy as np
import pandas as pd

# %%
smooth = {"s1": 24, "s2": 99, "s3": 175, "s4": 250}
scount = {"sc6": 79, "sc8": 125, "sc10": 168, "sc12": 225}
move = {"nomove": 0, "m83": 83, "m166": 166, "m250": 250}
eyes = {"noeyes": "false", "eyes": "true"}

count = 0

for s in smooth:
    for c in scount:
        for m in move:
            for e in eyes:
                string = "{complexity: "+str(scount[c])+", move: "+str(move[m]) + \
                ", smooth: " +str(smooth[s]) + ", eyes: "+ eyes[e]+"}"
                
                print(string)
                count +=1

print(count)
# Out:
# var bkk_s1_sc6_nomove_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 79, noise: 0, move: 0, smooth: 24, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s1_sc6_nomove_noeyes);
#
# var bkk_s1_sc6_nomove_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 79, noise: 0, move: 0, smooth: 24, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s1_sc6_nomove_eyes);
#
# var bkk_s1_sc6_m83_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 79, noise: 0, move: 83, smooth: 24, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s1_sc6_m83_noeyes);
#
# var bkk_s1_sc6_m83_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 79, noise: 0, move: 83, smooth: 24, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s1_sc6_m83_eyes);
#
# var bkk_s1_sc6_m166_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 79, noise: 0, move: 166, smooth: 24, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s1_sc6_m166_noeyes);
#
# var bkk_s1_sc6_m166_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 79, noise: 0, move: 166, smooth: 24, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s1_sc6_m166_eyes);
#
# var bkk_s1_sc6_m250_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 79, noise: 0, move: 250, smooth: 24, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s1_sc6_m250_noeyes);
#
# var bkk_s1_sc6_m250_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 79, noise: 0, move: 250, smooth: 24, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s1_sc6_m250_eyes);
#
# var bkk_s1_sc8_nomove_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 125, noise: 0, move: 0, smooth: 24, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s1_sc8_nomove_noeyes);
#
# var bkk_s1_sc8_nomove_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 125, noise: 0, move: 0, smooth: 24, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s1_sc8_nomove_eyes);
#
# var bkk_s1_sc8_m83_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 125, noise: 0, move: 83, smooth: 24, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s1_sc8_m83_noeyes);
#
# var bkk_s1_sc8_m83_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 125, noise: 0, move: 83, smooth: 24, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s1_sc8_m83_eyes);
#
# var bkk_s1_sc8_m166_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 125, noise: 0, move: 166, smooth: 24, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s1_sc8_m166_noeyes);
#
# var bkk_s1_sc8_m166_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 125, noise: 0, move: 166, smooth: 24, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s1_sc8_m166_eyes);
#
# var bkk_s1_sc8_m250_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 125, noise: 0, move: 250, smooth: 24, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s1_sc8_m250_noeyes);
#
# var bkk_s1_sc8_m250_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 125, noise: 0, move: 250, smooth: 24, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s1_sc8_m250_eyes);
#
# var bkk_s1_sc10_nomove_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 168, noise: 0, move: 0, smooth: 24, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s1_sc10_nomove_noeyes);
#
# var bkk_s1_sc10_nomove_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 168, noise: 0, move: 0, smooth: 24, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s1_sc10_nomove_eyes);
#
# var bkk_s1_sc10_m83_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 168, noise: 0, move: 83, smooth: 24, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s1_sc10_m83_noeyes);
#
# var bkk_s1_sc10_m83_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 168, noise: 0, move: 83, smooth: 24, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s1_sc10_m83_eyes);
#
# var bkk_s1_sc10_m166_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 168, noise: 0, move: 166, smooth: 24, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s1_sc10_m166_noeyes);
#
# var bkk_s1_sc10_m166_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 168, noise: 0, move: 166, smooth: 24, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s1_sc10_m166_eyes);
#
# var bkk_s1_sc10_m250_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 168, noise: 0, move: 250, smooth: 24, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s1_sc10_m250_noeyes);
#
# var bkk_s1_sc10_m250_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 168, noise: 0, move: 250, smooth: 24, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s1_sc10_m250_eyes);
#
# var bkk_s1_sc12_nomove_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 225, noise: 0, move: 0, smooth: 24, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s1_sc12_nomove_noeyes);
#
# var bkk_s1_sc12_nomove_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 225, noise: 0, move: 0, smooth: 24, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s1_sc12_nomove_eyes);
#
# var bkk_s1_sc12_m83_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 225, noise: 0, move: 83, smooth: 24, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s1_sc12_m83_noeyes);
#
# var bkk_s1_sc12_m83_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 225, noise: 0, move: 83, smooth: 24, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s1_sc12_m83_eyes);
#
# var bkk_s1_sc12_m166_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 225, noise: 0, move: 166, smooth: 24, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s1_sc12_m166_noeyes);
#
# var bkk_s1_sc12_m166_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 225, noise: 0, move: 166, smooth: 24, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s1_sc12_m166_eyes);
#
# var bkk_s1_sc12_m250_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 225, noise: 0, move: 250, smooth: 24, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s1_sc12_m250_noeyes);
#
# var bkk_s1_sc12_m250_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 225, noise: 0, move: 250, smooth: 24, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s1_sc12_m250_eyes);
#
# var bkk_s2_sc6_nomove_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 79, noise: 0, move: 0, smooth: 99, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s2_sc6_nomove_noeyes);
#
# var bkk_s2_sc6_nomove_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 79, noise: 0, move: 0, smooth: 99, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s2_sc6_nomove_eyes);
#
# var bkk_s2_sc6_m83_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 79, noise: 0, move: 83, smooth: 99, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s2_sc6_m83_noeyes);
#
# var bkk_s2_sc6_m83_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 79, noise: 0, move: 83, smooth: 99, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s2_sc6_m83_eyes);
#
# var bkk_s2_sc6_m166_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 79, noise: 0, move: 166, smooth: 99, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s2_sc6_m166_noeyes);
#
# var bkk_s2_sc6_m166_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 79, noise: 0, move: 166, smooth: 99, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s2_sc6_m166_eyes);
#
# var bkk_s2_sc6_m250_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 79, noise: 0, move: 250, smooth: 99, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s2_sc6_m250_noeyes);
#
# var bkk_s2_sc6_m250_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 79, noise: 0, move: 250, smooth: 99, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s2_sc6_m250_eyes);
#
# var bkk_s2_sc8_nomove_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 125, noise: 0, move: 0, smooth: 99, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s2_sc8_nomove_noeyes);
#
# var bkk_s2_sc8_nomove_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 125, noise: 0, move: 0, smooth: 99, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s2_sc8_nomove_eyes);
#
# var bkk_s2_sc8_m83_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 125, noise: 0, move: 83, smooth: 99, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s2_sc8_m83_noeyes);
#
# var bkk_s2_sc8_m83_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 125, noise: 0, move: 83, smooth: 99, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s2_sc8_m83_eyes);
#
# var bkk_s2_sc8_m166_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 125, noise: 0, move: 166, smooth: 99, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s2_sc8_m166_noeyes);
#
# var bkk_s2_sc8_m166_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 125, noise: 0, move: 166, smooth: 99, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s2_sc8_m166_eyes);
#
# var bkk_s2_sc8_m250_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 125, noise: 0, move: 250, smooth: 99, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s2_sc8_m250_noeyes);
#
# var bkk_s2_sc8_m250_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 125, noise: 0, move: 250, smooth: 99, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s2_sc8_m250_eyes);
#
# var bkk_s2_sc10_nomove_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 168, noise: 0, move: 0, smooth: 99, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s2_sc10_nomove_noeyes);
#
# var bkk_s2_sc10_nomove_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 168, noise: 0, move: 0, smooth: 99, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s2_sc10_nomove_eyes);
#
# var bkk_s2_sc10_m83_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 168, noise: 0, move: 83, smooth: 99, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s2_sc10_m83_noeyes);
#
# var bkk_s2_sc10_m83_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 168, noise: 0, move: 83, smooth: 99, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s2_sc10_m83_eyes);
#
# var bkk_s2_sc10_m166_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 168, noise: 0, move: 166, smooth: 99, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s2_sc10_m166_noeyes);
#
# var bkk_s2_sc10_m166_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 168, noise: 0, move: 166, smooth: 99, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s2_sc10_m166_eyes);
#
# var bkk_s2_sc10_m250_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 168, noise: 0, move: 250, smooth: 99, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s2_sc10_m250_noeyes);
#
# var bkk_s2_sc10_m250_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 168, noise: 0, move: 250, smooth: 99, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s2_sc10_m250_eyes);
#
# var bkk_s2_sc12_nomove_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 225, noise: 0, move: 0, smooth: 99, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s2_sc12_nomove_noeyes);
#
# var bkk_s2_sc12_nomove_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 225, noise: 0, move: 0, smooth: 99, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s2_sc12_nomove_eyes);
#
# var bkk_s2_sc12_m83_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 225, noise: 0, move: 83, smooth: 99, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s2_sc12_m83_noeyes);
#
# var bkk_s2_sc12_m83_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 225, noise: 0, move: 83, smooth: 99, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s2_sc12_m83_eyes);
#
# var bkk_s2_sc12_m166_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 225, noise: 0, move: 166, smooth: 99, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s2_sc12_m166_noeyes);
#
# var bkk_s2_sc12_m166_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 225, noise: 0, move: 166, smooth: 99, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s2_sc12_m166_eyes);
#
# var bkk_s2_sc12_m250_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 225, noise: 0, move: 250, smooth: 99, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s2_sc12_m250_noeyes);
#
# var bkk_s2_sc12_m250_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 225, noise: 0, move: 250, smooth: 99, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s2_sc12_m250_eyes);
#
# var bkk_s3_sc6_nomove_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 79, noise: 0, move: 0, smooth: 175, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s3_sc6_nomove_noeyes);
#
# var bkk_s3_sc6_nomove_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 79, noise: 0, move: 0, smooth: 175, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s3_sc6_nomove_eyes);
#
# var bkk_s3_sc6_m83_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 79, noise: 0, move: 83, smooth: 175, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s3_sc6_m83_noeyes);
#
# var bkk_s3_sc6_m83_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 79, noise: 0, move: 83, smooth: 175, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s3_sc6_m83_eyes);
#
# var bkk_s3_sc6_m166_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 79, noise: 0, move: 166, smooth: 175, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s3_sc6_m166_noeyes);
#
# var bkk_s3_sc6_m166_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 79, noise: 0, move: 166, smooth: 175, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s3_sc6_m166_eyes);
#
# var bkk_s3_sc6_m250_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 79, noise: 0, move: 250, smooth: 175, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s3_sc6_m250_noeyes);
#
# var bkk_s3_sc6_m250_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 79, noise: 0, move: 250, smooth: 175, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s3_sc6_m250_eyes);
#
# var bkk_s3_sc8_nomove_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 125, noise: 0, move: 0, smooth: 175, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s3_sc8_nomove_noeyes);
#
# var bkk_s3_sc8_nomove_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 125, noise: 0, move: 0, smooth: 175, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s3_sc8_nomove_eyes);
#
# var bkk_s3_sc8_m83_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 125, noise: 0, move: 83, smooth: 175, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s3_sc8_m83_noeyes);
#
# var bkk_s3_sc8_m83_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 125, noise: 0, move: 83, smooth: 175, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s3_sc8_m83_eyes);
#
# var bkk_s3_sc8_m166_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 125, noise: 0, move: 166, smooth: 175, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s3_sc8_m166_noeyes);
#
# var bkk_s3_sc8_m166_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 125, noise: 0, move: 166, smooth: 175, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s3_sc8_m166_eyes);
#
# var bkk_s3_sc8_m250_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 125, noise: 0, move: 250, smooth: 175, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s3_sc8_m250_noeyes);
#
# var bkk_s3_sc8_m250_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 125, noise: 0, move: 250, smooth: 175, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s3_sc8_m250_eyes);
#
# var bkk_s3_sc10_nomove_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 168, noise: 0, move: 0, smooth: 175, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s3_sc10_nomove_noeyes);
#
# var bkk_s3_sc10_nomove_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 168, noise: 0, move: 0, smooth: 175, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s3_sc10_nomove_eyes);
#
# var bkk_s3_sc10_m83_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 168, noise: 0, move: 83, smooth: 175, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s3_sc10_m83_noeyes);
#
# var bkk_s3_sc10_m83_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 168, noise: 0, move: 83, smooth: 175, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s3_sc10_m83_eyes);
#
# var bkk_s3_sc10_m166_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 168, noise: 0, move: 166, smooth: 175, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s3_sc10_m166_noeyes);
#
# var bkk_s3_sc10_m166_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 168, noise: 0, move: 166, smooth: 175, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s3_sc10_m166_eyes);
#
# var bkk_s3_sc10_m250_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 168, noise: 0, move: 250, smooth: 175, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s3_sc10_m250_noeyes);
#
# var bkk_s3_sc10_m250_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 168, noise: 0, move: 250, smooth: 175, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s3_sc10_m250_eyes);
#
# var bkk_s3_sc12_nomove_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 225, noise: 0, move: 0, smooth: 175, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s3_sc12_nomove_noeyes);
#
# var bkk_s3_sc12_nomove_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 225, noise: 0, move: 0, smooth: 175, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s3_sc12_nomove_eyes);
#
# var bkk_s3_sc12_m83_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 225, noise: 0, move: 83, smooth: 175, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s3_sc12_m83_noeyes);
#
# var bkk_s3_sc12_m83_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 225, noise: 0, move: 83, smooth: 175, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s3_sc12_m83_eyes);
#
# var bkk_s3_sc12_m166_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 225, noise: 0, move: 166, smooth: 175, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s3_sc12_m166_noeyes);
#
# var bkk_s3_sc12_m166_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 225, noise: 0, move: 166, smooth: 175, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s3_sc12_m166_eyes);
#
# var bkk_s3_sc12_m250_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 225, noise: 0, move: 250, smooth: 175, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s3_sc12_m250_noeyes);
#
# var bkk_s3_sc12_m250_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 225, noise: 0, move: 250, smooth: 175, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s3_sc12_m250_eyes);
#
# var bkk_s4_sc6_nomove_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 79, noise: 0, move: 0, smooth: 250, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s4_sc6_nomove_noeyes);
#
# var bkk_s4_sc6_nomove_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 79, noise: 0, move: 0, smooth: 250, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s4_sc6_nomove_eyes);
#
# var bkk_s4_sc6_m83_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 79, noise: 0, move: 83, smooth: 250, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s4_sc6_m83_noeyes);
#
# var bkk_s4_sc6_m83_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 79, noise: 0, move: 83, smooth: 250, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s4_sc6_m83_eyes);
#
# var bkk_s4_sc6_m166_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 79, noise: 0, move: 166, smooth: 250, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s4_sc6_m166_noeyes);
#
# var bkk_s4_sc6_m166_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 79, noise: 0, move: 166, smooth: 250, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s4_sc6_m166_eyes);
#
# var bkk_s4_sc6_m250_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 79, noise: 0, move: 250, smooth: 250, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s4_sc6_m250_noeyes);
#
# var bkk_s4_sc6_m250_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 79, noise: 0, move: 250, smooth: 250, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s4_sc6_m250_eyes);
#
# var bkk_s4_sc8_nomove_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 125, noise: 0, move: 0, smooth: 250, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s4_sc8_nomove_noeyes);
#
# var bkk_s4_sc8_nomove_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 125, noise: 0, move: 0, smooth: 250, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s4_sc8_nomove_eyes);
#
# var bkk_s4_sc8_m83_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 125, noise: 0, move: 83, smooth: 250, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s4_sc8_m83_noeyes);
#
# var bkk_s4_sc8_m83_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 125, noise: 0, move: 83, smooth: 250, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s4_sc8_m83_eyes);
#
# var bkk_s4_sc8_m166_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 125, noise: 0, move: 166, smooth: 250, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s4_sc8_m166_noeyes);
#
# var bkk_s4_sc8_m166_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 125, noise: 0, move: 166, smooth: 250, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s4_sc8_m166_eyes);
#
# var bkk_s4_sc8_m250_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 125, noise: 0, move: 250, smooth: 250, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s4_sc8_m250_noeyes);
#
# var bkk_s4_sc8_m250_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 125, noise: 0, move: 250, smooth: 250, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s4_sc8_m250_eyes);
#
# var bkk_s4_sc10_nomove_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 168, noise: 0, move: 0, smooth: 250, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s4_sc10_nomove_noeyes);
#
# var bkk_s4_sc10_nomove_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 168, noise: 0, move: 0, smooth: 250, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s4_sc10_nomove_eyes);
#
# var bkk_s4_sc10_m83_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 168, noise: 0, move: 83, smooth: 250, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s4_sc10_m83_noeyes);
#
# var bkk_s4_sc10_m83_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 168, noise: 0, move: 83, smooth: 250, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s4_sc10_m83_eyes);
#
# var bkk_s4_sc10_m166_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 168, noise: 0, move: 166, smooth: 250, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s4_sc10_m166_noeyes);
#
# var bkk_s4_sc10_m166_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 168, noise: 0, move: 166, smooth: 250, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s4_sc10_m166_eyes);
#
# var bkk_s4_sc10_m250_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 168, noise: 0, move: 250, smooth: 250, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s4_sc10_m250_noeyes);
#
# var bkk_s4_sc10_m250_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 168, noise: 0, move: 250, smooth: 250, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s4_sc10_m250_eyes);
#
# var bkk_s4_sc12_nomove_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 225, noise: 0, move: 0, smooth: 250, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s4_sc12_nomove_noeyes);
#
# var bkk_s4_sc12_nomove_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 225, noise: 0, move: 0, smooth: 250, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s4_sc12_nomove_eyes);
#
# var bkk_s4_sc12_m83_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 225, noise: 0, move: 83, smooth: 250, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s4_sc12_m83_noeyes);
#
# var bkk_s4_sc12_m83_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 225, noise: 0, move: 83, smooth: 250, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s4_sc12_m83_eyes);
#
# var bkk_s4_sc12_m166_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 225, noise: 0, move: 166, smooth: 250, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s4_sc12_m166_noeyes);
#
# var bkk_s4_sc12_m166_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 225, noise: 0, move: 166, smooth: 250, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s4_sc12_m166_eyes);
#
# var bkk_s4_sc12_m250_noeyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 225, noise: 0, move: 250, smooth: 250, draw_eyes: false
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s4_sc12_m250_noeyes);
#
# var bkk_s4_sc12_m250_eyes{
#  	 type: jsPsychBKKSurveyText,
# 	 bkkColor:'#808080', spike: 237, complexity: 225, noise: 0, move: 250, smooth: 250, draw_eyes: true
#  	 gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}
# timeline_bkks.push(bkk_s4_sc12_m250_eyes);
#
# 128

# %%
#     var bkk_survey = { type: jsPsychBKKSurveyText, 
#       bkkColor:"#D7B27A", spike:127, complexity:127, noise: 127,move: 127, smooth: 127,
#       gui_show:false, circClick_required: true, preamble: bkk_preamble, questions: []}

# %%
((250) / 3) * 3
# Out:
# 250.0
